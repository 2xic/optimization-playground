# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from loss import SSIM, SSIM_block, gradient

# %% [markdown]
# ### SSIM

# %%
x = torch.ones((100, 100))
y = torch.rand((100, 100))

# %%
x[0:25, 0:25] = 255

# %%
plt.imshow(x)

# %%
plt.imshow(SSIM_block(x, x, 2))

# %%
SSIM_block(x, y).mean()
# Out:
# tensor(0.8884)

# %% [markdown]
# ### gradient

# %%
dx, dy = gradient((
    np.concatenate((
        x.numpy(),
    ), axis=0).astype(np.uint8)
))
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In [30], line 1
# ----> 1 dx, dy = gradient((
#       2 #    np.concatenate((
#       3         x.numpy().astype(np.uint8),
#       4 #    ), axis=0).astype(np.uint8)
#       5 ))
#
# File ~/Desktop/paper-zoo/cv/unsupervised_monocular_depth_esimtation/loss.py:130, in gradient(image)
#     120 kernel_x = np.array([
#     121     [1, 0, -1],
#     122     [1, 0, -1],
#     123     [1, 0, -1]
#     124 ])
#     125 kernel_y = np.array([
#     126     [1, 1, 1],
#     127     [0, 0, 0],
#     128     [-1, -1, -1]
#     129 ])
# --> 130 dx = cv2.filter2D(image, cv2.CV_8U, kernel_x)
#     131 dy = cv2.filter2D(image, cv2.CV_8U, kernel_y)
#     133 return (
#     134     dx,
#     135     dy
#     136 )
#
# error: OpenCV(4.6.0) :-1: error: (-5:Bad argument) in function 'filter2D'
# > Overload resolution failed:
# ...

# %%
plt.imshow(dx)

# %%
plt.imshow(dy)
